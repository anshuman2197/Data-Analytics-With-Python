# %%
 import numpy as np
 import pandas as pd
 import matplotlib.pyplot as plt
 import seaborn as sns

# %%
fifa=pd.read_csv('/content/fifa data.csv')
fifa
# Out:
#       sofifa_id                                         player_url  ...   rcb    rb
# 0        158023  https://sofifa.com/player/158023/lionel-messi/...  ...  52+2  63+2
# 1         20801  https://sofifa.com/player/20801/c-ronaldo-dos-...  ...  53+3  61+3
# 2        190871  https://sofifa.com/player/190871/neymar-da-sil...  ...  46+3  61+3
# 3        200389  https://sofifa.com/player/200389/jan-oblak/20/...  ...   NaN   NaN
# 4        183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
# ...         ...                                                ...  ...   ...   ...
# 6194     219413  https://sofifa.com/player/219413/edwin-velasco...  ...  65+2  67+2
# 6195     219655  https://sofifa.com/player/219655/francesco-zam...  ...  66+2  69+2
# 6196     219731  https://sofifa.com/player/219731/mattia-montin...  ...  40+2  42+2
# 6197     220089  https://sofifa.com/player/220089/salih-dursun/...  ...  68+2  64+2
# ...

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  ...   rcb    rb
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...  ...  52+2  63+2
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...  ...  53+3  61+3
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...  ...  46+3  61+3
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...  ...   NaN   NaN
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
#
# [5 rows x 104 columns]

# %%
fifa.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
for col in fifa.columns:
  print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa.shape
# Out:
# (6199, 104)

# %%
fifa['nationality'].value_counts()
# Out:
# Spain                   535
# Brazil                  520
# Argentina               476
# France                  386
# Germany                 364
#                        ...
# Bermuda                   1
# Kenya                     1
# Latvia                    1
# United Arab Emirates      1
# Montserrat                1
# Name: nationality, Length: 128, dtype: int64

# %%
fifa['nationality'].value_counts()[0:10]
# Out:
# Spain          535
# Brazil         520
# Argentina      476
# France         386
# Germany        364
# England        312
# Italy          303
# Portugal       201
# Colombia       173
# Netherlands    168
# Name: nationality, dtype: int64

# %%
fifa['nationality'].value_counts()[0:10].keys()
# Out:
# Index(['Spain', 'Brazil', 'Argentina', 'France', 'Germany', 'England', 'Italy',
#        'Portugal', 'Colombia', 'Netherlands'],
#       dtype='object')

# %%
plt.figure(figsize=(8,4))
plt.bar(list(fifa['nationality'].value_counts()[0:10].keys()),list(fifa['nationality'].value_counts()[0:10]),color="grey")
plt.show()

# %%
ps=fifa[['short_name','wage_eur']]

# %%
ps
# Out:
#              short_name  wage_eur
# 0              L. Messi    565000
# 1     Cristiano Ronaldo    405000
# 2             Neymar Jr    290000
# 3              J. Oblak    125000
# 4             E. Hazard    470000
# ...                 ...       ...
# 6194         E. Velasco      1000
# 6195         F. Zampano      2000
# 6196         M. Montini      6000
# 6197          S. Dursun      8000
# 6198     I. Bel Hassani      5000
#
# [6199 rows x 2 columns]

# %%
ps.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
ps1=ps.sort_values(by=['wage_eur'],ascending=False)

# %%
ps1.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
plt.figure(figsize=(8,5))
plt.bar(list(ps1['short_name'])[0:5],list(ps1['wage_eur'])[0:5],color=['blue','green','red','pink','orange'])
plt.show()

# %%
german=fifa[fifa['nationality']=='Germany']
german
# Out:
#       sofifa_id                                         player_url  ...   rcb    rb
# 6        192448  https://sofifa.com/player/192448/marc-andre-te...  ...   NaN   NaN
# 31       167495  https://sofifa.com/player/167495/manuel-neuer/...  ...   NaN   NaN
# 36       182521  https://sofifa.com/player/182521/toni-kroos/20...  ...  69+3  72+3
# 37       188350  https://sofifa.com/player/188350/marco-reus/20...  ...  55+3  64+3
# 49       178603  https://sofifa.com/player/178603/mats-hummels/...  ...  84+3  78+3
# ...         ...                                                ...  ...   ...   ...
# 6162     202512  https://sofifa.com/player/202512/florian-harth...  ...  66+2  68+2
# 6165     203026  https://sofifa.com/player/203026/petar-filipov...  ...  67+2  66+2
# 6180     210042  https://sofifa.com/player/210042/johannes-wurt...  ...  64+2  63+2
# 6181     211946  https://sofifa.com/player/211946/markus-kolke/...  ...   NaN   NaN
# ...

# %%
german.sort_values(by=['height_cm'],ascending=False).head()
# Out:
#       sofifa_id                                         player_url  ...   rcb    rb
# 1389     199833  https://sofifa.com/player/199833/lars-unnersta...  ...   NaN   NaN
# 1217     200212  https://sofifa.com/player/200212/michael-esser...  ...   NaN   NaN
# 518      179783  https://sofifa.com/player/179783/ralf-fahrmann...  ...   NaN   NaN
# 4449     158657  https://sofifa.com/player/158657/thomas-kessle...  ...   NaN   NaN
# 5107     216284  https://sofifa.com/player/216284/florian-balla...  ...  69+2  57+2
#
# [5 rows x 104 columns]

# %%
german.sort_values(by=['weight_kg'],ascending=False).head(5)
# Out:
#       sofifa_id                                         player_url  ...   rcb    rb
# 1389     199833  https://sofifa.com/player/199833/lars-unnersta...  ...   NaN   NaN
# 518      179783  https://sofifa.com/player/179783/ralf-fahrmann...  ...   NaN   NaN
# 1217     200212  https://sofifa.com/player/200212/michael-esser...  ...   NaN   NaN
# 165      213331  https://sofifa.com/player/213331/jonathan-tah/...  ...  81+2  73+2
# 77       212190  https://sofifa.com/player/212190/niklas-sule/2...  ...  83+2  75+2
#
# [5 rows x 104 columns]

# %%
shoot=fifa[['short_name','shooting']]
shoot.head(5)
# Out:
#           short_name  shooting
# 0           L. Messi      92.0
# 1  Cristiano Ronaldo      93.0
# 2          Neymar Jr      85.0
# 3           J. Oblak       NaN
# 4          E. Hazard      83.0

# %%
defending=fifa[['short_name','defending','nationality','club']]
defending.head()
# Out:
#           short_name  defending nationality                 club
# 0           L. Messi       39.0   Argentina         FC Barcelona
# 1  Cristiano Ronaldo       35.0    Portugal             Juventus
# 2          Neymar Jr       32.0      Brazil  Paris Saint-Germain
# 3           J. Oblak        NaN    Slovenia      Atlético Madrid
# 4          E. Hazard       35.0     Belgium          Real Madrid

# %%
real=fifa[fifa['club']=='Real Madrid']
real
# Out:
#       sofifa_id                                         player_url  ...   rcb    rb
# 4        183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
# 8        177003  https://sofifa.com/player/177003/luka-modric/2...  ...  72+3  79+3
# 18       155862  https://sofifa.com/player/155862/sergio-ramos-...  ...  87+3  82+3
# 28       192119  https://sofifa.com/player/192119/thibaut-court...  ...   NaN   NaN
# 36       182521  https://sofifa.com/player/182521/toni-kroos/20...  ...  69+3  72+3
# 42       200145  https://sofifa.com/player/200145/carlos-henriq...  ...  84+3  79+3
# 46       165153  https://sofifa.com/player/165153/karim-benzema...  ...  54+3  58+3
# 53       193041  https://sofifa.com/player/193041/keylor-navas/...  ...   NaN   NaN
# 62       197781  https://sofifa.com/player/197781/francisco-rom...  ...  62+3  67+3
# 76       201535  https://sofifa.com/player/201535/raphael-varan...  ...  83+3  77+3
# ...
