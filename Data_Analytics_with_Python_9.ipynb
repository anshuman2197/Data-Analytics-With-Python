# %% [markdown]
# # Udemy Courses

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('/content/7. Udemy Courses.csv')
data
# Out:
#       course_id  ...              subject
# 0        288942  ...  Musical Instruments
# 1       1170074  ...  Musical Instruments
# 2       1193886  ...  Musical Instruments
# 3       1116700  ...  Musical Instruments
# 4       1120410  ...  Musical Instruments
# ...         ...  ...                  ...
# 3677     328960  ...      Web Development
# 3678     552700  ...  Musical Instruments
# 3679     631754  ...      Web Development
# 3680    1225194  ...     Business Finance
# 3681     964478  ...       Graphic Design
#
# [3682 rows x 11 columns]

# %%
data.head()
# Out:
#    course_id  ...              subject
# 0     288942  ...  Musical Instruments
# 1    1170074  ...  Musical Instruments
# 2    1193886  ...  Musical Instruments
# 3    1116700  ...  Musical Instruments
# 4    1120410  ...  Musical Instruments
#
# [5 rows x 11 columns]

# %% [markdown]
# # What all different subject for which Udemy offering courses?

# %%
data.head(2)
# Out:
#    course_id  ...              subject
# 0     288942  ...  Musical Instruments
# 1    1170074  ...  Musical Instruments
#
# [2 rows x 11 columns]

# %%
data.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %% [markdown]
# # What Subjects has the maximum number of courses

# %%
data.head(1)
# Out:
#    course_id  ...              subject
# 0     288942  ...  Musical Instruments
#
# [1 rows x 11 columns]

# %%
data.subject.value_counts()
# Out:
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %% [markdown]
# # Show all the courses which are free of cost

# %%
data.head(1)
# Out:
#    course_id  ...              subject
# 0     288942  ...  Musical Instruments
#
# [1 rows x 11 columns]

# %%
data[data.is_paid==False]
# Out:
#       course_id  ...              subject
# 41       286070  ...  Musical Instruments
# 49       696630  ...  Musical Instruments
# 57       955914  ...  Musical Instruments
# 67       270976  ...      Web Development
# 74      1214144  ...     Business Finance
# ...         ...  ...                  ...
# 3620     552598  ...      Web Development
# 3638    1068590  ...      Web Development
# 3652     752706  ...      Web Development
# 3674    1257976  ...  Musical Instruments
# 3680    1225194  ...     Business Finance
#
# [310 rows x 11 columns]

# %% [markdown]
# # Show all courses which are paid

# %%
data[data.is_paid==True]
# Out:
#       course_id  ...              subject
# 0        288942  ...  Musical Instruments
# 1       1170074  ...  Musical Instruments
# 2       1193886  ...  Musical Instruments
# 3       1116700  ...  Musical Instruments
# 4       1120410  ...  Musical Instruments
# ...         ...  ...                  ...
# 3676     498488  ...     Business Finance
# 3677     328960  ...      Web Development
# 3678     552700  ...  Musical Instruments
# 3679     631754  ...      Web Development
# 3681     964478  ...       Graphic Design
#
# [3372 rows x 11 columns]

# %% [markdown]
# # Which are Top Selling Courses

# %%
data.head(1)
# Out:
#    course_id  ...              subject
# 0     288942  ...  Musical Instruments
#
# [1 rows x 11 columns]

# %%
data.sort_values('num_subscribers',ascending=False)
# Out:
#       course_id  ...              subject
# 2230      41295  ...      Web Development
# 776       59014  ...      Web Development
# 3385     625204  ...      Web Development
# 640      173548  ...      Web Development
# 3316     764164  ...      Web Development
# ...         ...  ...                  ...
# 2290    1223240  ...  Musical Instruments
# 1267    1258666  ...     Business Finance
# 2070    1215926  ...     Business Finance
# 1931    1247992  ...     Business Finance
# 3165    1087466  ...     Business Finance
#
# [3682 rows x 11 columns]

# %% [markdown]
# # Which are Least Selling Courses

# %%
data.sort_values('num_subscribers',ascending=True)
# Out:
#       course_id  ...           subject
# 649     1233314  ...  Business Finance
# 3259    1232282  ...  Business Finance
# 3261    1275872  ...    Graphic Design
# 910      726314  ...    Graphic Design
# 3328     715476  ...  Business Finance
# ...         ...  ...               ...
# 3316     764164  ...   Web Development
# 640      173548  ...   Web Development
# 3385     625204  ...   Web Development
# 776       59014  ...   Web Development
# 2230      41295  ...   Web Development
#
# [3682 rows x 11 columns]

# %% [markdown]
# # Show all the courses of Graphic Design where all the courses price is beloww 100

# %%
data.head(1)
# Out:
#    course_id  ...              subject
# 0     288942  ...  Musical Instruments
#
# [1 rows x 11 columns]

# %%
data[data.subject=='Graphic Design']
# Out:
#       course_id  ...         subject
# 8        206592  ...  Graphic Design
# 20      1165268  ...  Graphic Design
# 35      1164876  ...  Graphic Design
# 39       599652  ...  Graphic Design
# 47      1269190  ...  Graphic Design
# ...         ...  ...             ...
# 3588    1131780  ...  Graphic Design
# 3594     908664  ...  Graphic Design
# 3639    1122306  ...  Graphic Design
# 3671     144222  ...  Graphic Design
# 3681     964478  ...  Graphic Design
#
# [603 rows x 11 columns]

# %%
data[data.price<='100']
# Out:
#       course_id  ...           subject
# 11        64605  ...   Web Development
# 14        72262  ...   Web Development
# 47      1269190  ...    Graphic Design
# 50       665042  ...   Web Development
# 135      262370  ...  Business Finance
# ...         ...  ...               ...
# 3572     542254  ...   Web Development
# 3594     908664  ...    Graphic Design
# 3613     384318  ...   Web Development
# 3645    1271430  ...  Business Finance
# 3670     560996  ...   Web Development
#
# [133 rows x 11 columns]

# %%
data[(data.subject=='Graphic Design') & (data.price<='100')]
# Out:
#       course_id  ...         subject
# 47      1269190  ...  Graphic Design
# 169      983444  ...  Graphic Design
# 184      638040  ...  Graphic Design
# 520      978462  ...  Graphic Design
# 699      757900  ...  Graphic Design
# 1029    1160004  ...  Graphic Design
# 1071    1161864  ...  Graphic Design
# 1444     490392  ...  Graphic Design
# 1568     727510  ...  Graphic Design
# 1616     996868  ...  Graphic Design
# 1697     654038  ...  Graphic Design
# 1773    1012262  ...  Graphic Design
# 1786    1246168  ...  Graphic Design
# 1797    1266468  ...  Graphic Design
# 2137     927186  ...  Graphic Design
# 2481    1027080  ...  Graphic Design
# 2491     771044  ...  Graphic Design
# 2576     482924  ...  Graphic Design
# 2704     950894  ...  Graphic Design
# 2706    1243016  ...  Graphic Design
# 2713    1147664  ...  Graphic Design
# 3479     575040  ...  Graphic Design
# 3594     908664  ...  Graphic Design
#
# [23 rows x 11 columns]

# %% [markdown]
# # List out all the courses that are related with Python

# %%
data[data.course_title.str.contains('Python')]
# Out:
#       course_id  ...           subject
# 216      599504  ...   Web Development
# 777       47963  ...   Web Development
# 814      631128  ...   Web Development
# 842      186096  ...   Web Development
# 1400     394832  ...   Web Development
# 1932    1038538  ...   Web Development
# 1969     902888  ...  Business Finance
# 2294     391546  ...   Web Development
# 2295    1063722  ...   Web Development
# 2341     546848  ...    Graphic Design
# 2906     368340  ...   Web Development
# 2908    1035940  ...   Web Development
# 2929     270808  ...   Web Development
# 2952    1170894  ...  Business Finance
# 2953    1070886  ...  Business Finance
# 2954    1196544  ...  Business Finance
# 2955     822444  ...   Web Development
# 2956     477702  ...   Web Development
# 2957    1035472  ...  Business Finance
# 2958     529828  ...  Business Finance
# 2959      70640  ...   Web Development
# 2960     523312  ...   Web Development
# 2962    1088656  ...  Business Finance
# ...

# %% [markdown]
# # What are the courses that publish in 2015

# %%
data.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
df=data['published_timestamp']=pd.to_datetime(data.published_timestamp)

# %%
df
# Out:
# 0      2014-09-18 05:07:05+00:00
# 1      2017-04-12 19:06:34+00:00
# 2      2017-04-26 18:34:57+00:00
# 3      2017-02-21 23:48:18+00:00
# 4      2017-02-21 23:44:49+00:00
#                   ...
# 3677   2015-04-20 22:15:17+00:00
# 3678   2015-10-26 20:04:21+00:00
# 3679   2015-11-11 18:55:45+00:00
# 3680   2017-05-26 16:45:55+00:00
# 3681   2016-09-26 22:19:48+00:00
# Name: published_timestamp, Length: 3682, dtype: datetime64[ns, UTC]

# %%
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# is_paid                               bool
# price                               object
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                    object
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
data.head(1)
# Out:
#    course_id  ...              subject
# 0     288942  ...  Musical Instruments
#
# [1 rows x 11 columns]

# %%
data['Year']=data['published_timestamp'].dt.year

# %%
data.head(1)
# Out:
#    course_id  ...  Year
# 0     288942  ...  2014
#
# [1 rows x 12 columns]

# %%
data[data.Year==2015]
# Out:
#       course_id  ...  Year
# 10       591880  ...  2015
# 16       302450  ...  2015
# 19       384928  ...  2015
# 23       550842  ...  2015
# 26       486240  ...  2015
# ...         ...  ...   ...
# 3675     551170  ...  2015
# 3676     498488  ...  2015
# 3677     328960  ...  2015
# 3678     552700  ...  2015
# 3679     631754  ...  2015
#
# [1014 rows x 12 columns]

# %% [markdown]
# # What are the maximum number of Subscriber For each Level of courses

# %%
data.head(1)
# Out:
#    course_id  ...  Year
# 0     288942  ...  2014
#
# [1 rows x 12 columns]

# %%
data.level.unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
data.groupby('level')['num_subscribers'].sum()
# Out:
# level
# All Levels            6916112
# Beginner Level        4052843
# Expert Level            50196
# Intermediate Level     742005
# Name: num_subscribers, dtype: int64

# %%
data.groupby('level').max()
# Out:
#                     course_id  ...  Year
# level                          ...
# All Levels            1277924  ...  2017
# Beginner Level        1282064  ...  2017
# Expert Level          1275790  ...  2017
# Intermediate Level    1276182  ...  2017
#
# [4 rows x 11 columns]
