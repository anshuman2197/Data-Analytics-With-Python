# %% [markdown]
# # Matplotlib

# %%
# Matplotlib is one of the most popular Python Package used in Data Visualization.
# It was created by Jpohn D. Hunter in 2003.
# It is open source and we use it freely.
# It is mostly written in python, a few segment are written in C obnjective and Javascript for Platform compatibility.

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.array([1,2,3,4])
y=np.array([10,20,30,40])

plt.plot(x,y)
plt.show()

# %%
x=np.array([1,2,3,4])
y=np.array([10,20,30,40])

plt.plot(x,y,color='r')
plt.show()

# %%
ypoints=np.array([3,14,5,16,7,8])
plt.plot(ypoints)
plt.show()

# %%
days=list(range(0,22,3))
cel=[25.6,24.1,26.7,28.3,27.5,30.5,32.8,33.1]

plt.plot(days,cel)
plt.show()

# %%
x=np.arange(1,11)
y=np.exp(x) 

plt.plot(x,y)
plt.show()

# %%
y=np.array([3,8,1,10])
plt.plot(y,linestyle='dotted')
plt.show()

# %%
y=np.array([3,8,1,10])
plt.plot(y,linestyle=':')
plt.show()

# %%
y=np.array([3,8,1,10])
plt.plot(y,linestyle='-.')
plt.show()

# %%
y=np.array([3,8,1,10])
plt.plot(y,linestyle='--')
plt.show()

# %%
y=np.array([3,8,1,10])
plt.plot(y,linestyle='dotted',color='green')
plt.show()

# %%
y=np.array([3,8,1,10])
plt.plot(y,linestyle='dotted',linewidth=12)
plt.show()

# %%
y=np.array([3,8,1,10])
y1=np.array([5,9,6,2])
plt.plot(y,linestyle='dotted')
plt.plot(y1,linestyle='--')
plt.show()

# %%
y=np.array([3,8,1,10])
plt.plot(y,marker='o')

plt.show()

# %%
y=np.array([3,8,1,10])
plt.plot(y,marker='o',mec='r')

plt.show()

# %%
y=np.array([3,8,1,10])
plt.plot(y,marker='o',ms='20')

plt.show()

# %%
n=256

x=np.linspace(-np.pi,np.pi,n,endpoint=True)
y=np.sin(2*x)

plt.plot(x,y,color='blue')
plt.show()

# %%
x1=np.array([0,1,2,3])
y1=np.array([3,8,1,10])
x2=np.array([0,1,2,3])
y2=np.array([6,2,7,11])

plt.plot(x1,y1,x2,y2)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
y=[1,4,9,16,25,36,49,64]
x1=[1,16,30,42,55,68,77,88]
x2=[1,6,12,18,28,40,52,65]

plt.plot(x1,y,'ys--')
plt.plot(x2,y,'go--')
plt.legend(labels=('tv','smartphone'),loc='Lower right')
plt.grid(True)
plt.title('Ad effects on')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Unrecognized location 'Lower right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   import sys

# %%
y=[1,4,9,16,25,36,49,64]
x1=[1,16,30,42,55,68,77,88]
x2=[1,6,12,18,28,40,52,65]

plt.plot(x1,y,'ys--')
plt.plot(x2,y,'go--')
plt.legend(labels=('tv','smartphone'),loc='Lower right')
plt.grid(color='b',ls='-',lw=0.25)
plt.title('Ad effects on')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Unrecognized location 'Lower right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   import sys

# %%
y=[1,4,9,16,25,36,49,64]
x1=[1,16,30,42,55,68,77,88]
x2=[1,6,12,18,28,40,52,65]

plt.plot(x1,y,'ys--')
plt.plot(x2,y,'go--')
plt.legend(labels=('tv','smartphone'),loc='lower right')
plt.grid(True)
plt.show()

# %%
import numpy as np

# %%
x=np.array(['A','B','C','D'])
y=np.array([3,8,1,10])

plt.bar(x,y)
plt.show()

# %%
x=np.array(['A','B','C','D'])
y=np.array([3,8,1,10])

plt.barh(x,y)
plt.show()

# %%
x=np.array(['A','B','C','D'])
y=np.array([3,8,1,10])

plt.bar(x,y,color='green')
plt.show()

# %%
men=[20,35,30,35,27]
women=[25,12,34,20,25]
group=np.arange(5)

plt.bar(group,men,width=.35,color='r')
plt.bar(group,women,width=0.35,color='b',bottom=men)

plt.xlabel('Scores')
plt.ylabel('Groups')
plt.xticks(group,('G1','G2','G3','G4'))
plt.yticks(np.arange(0,81,10))
plt.show()

# %%
lans=np.array(['C','C++','Java','Python'])

plt.hist(lans)
plt.show()

# %%
x=np.random.normal(170,10,250)

plt.hist(x)
plt.show()

# %%
x=np.random.normal(170,10,250)

plt.hist(x,density=True)
plt.show()

# %%
y=np.array([35,25,25,15])

plt.pie(y)
plt.show()

# %%
y=np.array([35,25,25,15])
lb=['Apple','Banana','Cherry','Pear']

plt.pie(y,labels=lb)
plt.show()

# %%
y=np.array([35,25,25,15])
lb=['Apple','Banana','Cherry','Pear']

plt.pie(y,labels=lb,startangle=189)
plt.show()

# %%
y=np.array([35,25,25,15])
lb=['Apple','Banana','Cherry','Pear']
exp=[0.2,0,0,0]

plt.pie(y,labels=lb,explode=exp)
plt.show()

# %%
y=np.array([35,25,25,15])
lb=['Apple','Banana','Cherry','Pear']
exp=[0.2,0,0,0]

plt.pie(y,labels=lb,explode=exp,shadow=True)
plt.show()

# %%
y=np.array([35,25,25,15])
lb=['Apple','Banana','Cherry','Pear']
exp=[0.2,0,0,0]

plt.pie(y,labels=lb,explode=exp,autopct='%1.2f%%')
plt.show()

# %%
import numpy as np

# %%
x=np.array([5,7,8,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,111,86,103,87,94,78,77,85,86])


x=np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12,9,6])
y=np.array([100,105,84,105,90,99,90,95,94,100,79,100,79,112,91,85,86])

plt.scatter(x,y)
plt.show()

# %%
x=np.array([5,7,8,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,111,86,103,87,94,78,77,85,86])


# x=np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12,9,6])
# y=np.array([100,105,84,105,90,99,90,95,94,100,79,100,79,112,91,85,86])

colors=np.array([0,10,20,30,40,45,50,60,70,80,90,100])
plt.scatter(x,y,c=colors,cmap='viridis')
plt.colorbar()
plt.show()

# %%
x=np.array([5,7,8,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,111,86,103,87,94,78,77,85,86])


# x=np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12,9,6])
# y=np.array([100,105,84,105,90,99,90,95,94,100,79,100,79,112,91,85,86])

size=np.array([20,50,60,100,140,245,350,460,570,780,890,900])
plt.scatter(x,y,s=size,cmap='viridis')
plt.colorbar()
plt.show()

# %%
x=np.array([5,7,8,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,111,86,103,87,94,78,77,85,86])


# x=np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12,9,6])
# y=np.array([100,105,84,105,90,99,90,95,94,100,79,100,79,112,91,85,86])

size=np.array([20,50,60,100,140,245,350,460,570,780,890,900])
plt.scatter(x,y,s=size,cmap='viridis',alpha=0.5)
plt.colorbar()
plt.show()

# %%
x=np.random.randint(100,size=(100))
y=np.random.randint(100,size=(100))
colors=np.random.randint(100,size=(100))
size=10*np.random.randint(100,size=(100))

plt.scatter(x,y,c=colors,s=size,alpha=0.5,cmap='nipy_spectral')
plt.colorbar()
plt.show()

# %%
np.random.seed(10)
data=np.random.normal(100,20,200)

fig=plt.figure(figsize=(10,7))
plt.boxplot(data)
plt.show()

# %%
np.random.seed(10)
data1=np.random.normal(100,10,200)
data2=np.random.normal(90,20,200)
data3=np.random.normal(80,30,200)
data4=np.random.normal(70,40,200)

data=[data1,data2,data3,data4]
fig=plt.figure(figsize=(10,7))

plt.boxplot(data)
plt.show()

# %%
from mpl_toolkits import mplot3d
fig=plt.figure()
ax=plt.axes(projection='3d')

z=np.linspace(0,1,100)
x=z*np.sin(20*z)
y=z*np.cos(20*z)

ax.plot(x,y,z,'grey')
plt.show()

# %%
from mpl_toolkits import mplot3d
fig=plt.figure()
ax=plt.axes(projection='3d')

z=np.linspace(0,1,100)
x=z*np.sin(20*z)
y=z*np.cos(20*z)

ax.scatter(x,y,z,'grey')
plt.show()

# %%
x=np.outer(np.linspace(-2,2,30),np.ones(30))
y=x.copy().T
z=np.cos(x**2+y**2)

fig=plt.figure()
ax=plt.axes(projection='3d')

ax.plot_surface(x,y,z,cmap='viridis',edgecolor='none')
plt.show()

# %%
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(2,1,1)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(2,1,2)
plt.plot(x,y)

plt.show()

# %%
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(1,2,1)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(1,2,2)
plt.plot(x,y)
 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

import ipywidgets as widgets
from IPython.display import display

# %%
import os

# %%
def Exponent(maxIteration):
  x=np.arange(5*maxIteration)
  y=np.exp(x)


  plt.scatter(x,y,color='g',marker='o')
  plt.xlabel('X')
  plt.ylabel('Y')
  plt.show()

maxIteration=widgets.Play(min=1,max=1000,value=1,description='Iter')
widgets.interactive(Exponent,maxIteration=maxIteration)
# Out:
# interactive(children=(Play(value=1, description='Iter', max=1000, min=1), Output()), _dom_classes=('widget-int…
